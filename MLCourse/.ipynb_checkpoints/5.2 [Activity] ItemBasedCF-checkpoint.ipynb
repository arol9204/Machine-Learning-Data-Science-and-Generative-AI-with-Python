# %% [markdown]
# # Item-Based Collaborative Filtering

# %% [markdown]
# As before, we'll start by importing the MovieLens 100K data set into a pandas DataFrame:

# %%
import pandas as pd

r_cols = ['user_id', 'movie_id', 'rating']
ratings = pd.read_csv('ml-100k/u.data', sep='\t', names=r_cols, usecols=range(3), encoding="ISO-8859-1")

m_cols = ['movie_id', 'title']
movies = pd.read_csv('ml-100k/u.item', sep='|', names=m_cols, usecols=range(2), encoding="ISO-8859-1")

ratings = pd.merge(movies, ratings)

ratings.head()
# Out:
#    movie_id             title  user_id  rating
# 0         1  Toy Story (1995)      308       4
# 1         1  Toy Story (1995)      287       5
# 2         1  Toy Story (1995)      148       4
# 3         1  Toy Story (1995)      280       4
# 4         1  Toy Story (1995)       66       3

# %% [markdown]
# Now we'll pivot this table to construct a nice matrix of users and the movies they rated. NaN indicates missing data, or movies that a given user did not watch:

# %%
userRatings = ratings.pivot_table(index=['user_id'],columns=['title'],values='rating')
userRatings.head()
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# 1                        5.0         NaN                          NaN
# 2                        NaN         NaN                          NaN
# 3                        NaN         2.0                          NaN
# 4                        NaN         NaN                          NaN
#
# title    20,000 Leagues Under the Sea (1954)  2001: A Space Odyssey (1968)  \
# user_id
# ...

# %% [markdown]
# Now the magic happens - pandas has a built-in corr() method that will compute a correlation score for every column pair in the matrix! This gives us a correlation score between every pair of movies (where at least one user rated both movies - otherwise NaN's will show up.) That's amazing!

# %%
corrMatrix = userRatings.corr()
corrMatrix.head()
# Out:
# title                      'Til There Was You (1997)  1-900 (1994)  \
# title
# 'Til There Was You (1997)                        1.0           NaN
# 1-900 (1994)                                     NaN           1.0
# 101 Dalmatians (1996)                           -1.0           NaN
# 12 Angry Men (1957)                             -0.5           NaN
# 187 (1997)                                      -0.5           NaN
#
# title                      101 Dalmatians (1996)  12 Angry Men (1957)  \
# title
# 'Til There Was You (1997)              -1.000000            -0.500000
# 1-900 (1994)                                 NaN                  NaN
# 101 Dalmatians (1996)                   1.000000            -0.049890
# 12 Angry Men (1957)                    -0.049890             1.000000
# 187 (1997)                              0.269191             0.666667
#
# title                      187 (1997)  2 Days in the Valley (1996)  \
# title
# ...

# %% [markdown]
# However, we want to avoid spurious results that happened from just a handful of users that happened to rate the same pair of movies. In order to restrict our results to movies that lots of people rated together - and also give us more popular results that are more easily recongnizable - we'll use the min_periods argument to throw out results where fewer than 100 users rated a given movie pair:

# %%
corrMatrix = userRatings.corr(method='pearson', min_periods=100)
corrMatrix.head()
# Out:
# title                      'Til There Was You (1997)  1-900 (1994)  \
# title
# 'Til There Was You (1997)                        NaN           NaN
# 1-900 (1994)                                     NaN           NaN
# 101 Dalmatians (1996)                            NaN           NaN
# 12 Angry Men (1957)                              NaN           NaN
# 187 (1997)                                       NaN           NaN
#
# title                      101 Dalmatians (1996)  12 Angry Men (1957)  \
# title
# 'Til There Was You (1997)                    NaN                  NaN
# 1-900 (1994)                                 NaN                  NaN
# 101 Dalmatians (1996)                        1.0                  NaN
# 12 Angry Men (1957)                          NaN                  1.0
# 187 (1997)                                   NaN                  NaN
#
# title                      187 (1997)  2 Days in the Valley (1996)  \
# title
# ...

# %% [markdown]
# Now let's produce some movie recommendations for user ID 0, who I manually added to the data set as a test case. This guy really likes Star Wars and The Empire Strikes Back, but hated Gone with the Wind. I'll extract his ratings from the userRatings DataFrame, and use dropna() to get rid of missing data (leaving me only with a Series of the movies I actually rated:)

# %%
myRatings = userRatings.loc[0].dropna()
myRatings
# Out:
# title
# Empire Strikes Back, The (1980)    5.0
# Gone with the Wind (1939)          1.0
# Star Wars (1977)                   5.0
# Name: 0, dtype: float64

# %% [markdown]
# Now, let's go through each movie I rated one at a time, and build up a list of possible recommendations based on the movies similar to the ones I rated.
#
# So for each movie I rated, I'll retrieve the list of similar movies from our correlation matrix. I'll then scale those correlation scores by how well I rated the movie they are similar to, so movies similar to ones I liked count more than movies similar to ones I hated:

# %%
corrMatrix[myRatings.index[1]].dropna().sort_values(ascending = False)
# Out:
# title
# Gone with the Wind (1939)                       1.000000
# Wizard of Oz, The (1939)                        0.430219
# E.T. the Extra-Terrestrial (1982)               0.361463
# Schindler's List (1993)                         0.344765
# Graduate, The (1967)                            0.326215
# Amadeus (1984)                                  0.323631
# M*A*S*H (1970)                                  0.313956
# It's a Wonderful Life (1946)                    0.305688
# Casablanca (1942)                               0.291137
# Back to the Future (1985)                       0.257319
# Mary Poppins (1964)                             0.244310
# Sound of Music, The (1965)                      0.244235
# Return of the Jedi (1983)                       0.209247
# Toy Story (1995)                                0.199741
# When Harry Met Sally... (1989)                  0.197863
# Psycho (1960)                                   0.193419
# ...

# %%
corrMatrix
# Out:
# title                                  'Til There Was You (1997)  \
# title
# 'Til There Was You (1997)                                    NaN
# 1-900 (1994)                                                 NaN
# 101 Dalmatians (1996)                                        NaN
# 12 Angry Men (1957)                                          NaN
# 187 (1997)                                                   NaN
# ...                                                          ...
# Young Guns II (1990)                                         NaN
# Young Poisoner's Handbook, The (1995)                        NaN
# Zeus and Roxanne (1997)                                      NaN
# unknown                                                      NaN
# Á köldum klaka (Cold Fever) (1994)                           NaN
#
# title                                  1-900 (1994)  101 Dalmatians (1996)  \
# title
# 'Til There Was You (1997)                       NaN                    NaN
# ...

# %%
myRatings
# Out:
# title
# Empire Strikes Back, The (1980)    5.0
# Gone with the Wind (1939)          1.0
# Star Wars (1977)                   5.0
# Name: 0, dtype: float64

# %%
simCandidates = pd.Series()
for i in range(0, len(myRatings.index)):
    print ("Adding sims for " + myRatings.index[i] + "...")
    # Retrieve similar movies to this one that I rated
    sims = corrMatrix[myRatings.index[i]].dropna()
    # Now scale its similarity by how well I rated this movie
    sims = sims.map(lambda x: x * myRatings[i])
    # Add the score to the list of similarity candidates
    simCandidates = simCandidates.append(sims)
    
#Glance at our results so far:
print ("sorting...")
simCandidates.sort_values(inplace = True, ascending = False)
print (simCandidates.head(10))
# Out:
# Adding sims for Empire Strikes Back, The (1980)...
# Adding sims for Gone with the Wind (1939)...
# Adding sims for Star Wars (1977)...
# sorting...
# Empire Strikes Back, The (1980)                       5.000000
# Star Wars (1977)                                      5.000000
# Empire Strikes Back, The (1980)                       3.741763
# Star Wars (1977)                                      3.741763
# Return of the Jedi (1983)                             3.606146
# Return of the Jedi (1983)                             3.362779
# Raiders of the Lost Ark (1981)                        2.693297
# Raiders of the Lost Ark (1981)                        2.680586
# Austin Powers: International Man of Mystery (1997)    1.887164
# Sting, The (1973)                                     1.837692
# dtype: float64
# ...

# %% [markdown]
# This is starting to look like something useful! Note that some of the same movies came up more than once, because they were similar to more than one movie I rated. We'll use groupby() to add together the scores from movies that show up more than once, so they'll count more:

# %%
simCandidates = simCandidates.groupby(simCandidates.index).sum()

# %%
simCandidates.sort_values(inplace = True, ascending = False)
simCandidates.head(10)
# Out:
# Empire Strikes Back, The (1980)              8.877450
# Star Wars (1977)                             8.870971
# Return of the Jedi (1983)                    7.178172
# Raiders of the Lost Ark (1981)               5.519700
# Indiana Jones and the Last Crusade (1989)    3.488028
# Bridge on the River Kwai, The (1957)         3.366616
# Back to the Future (1985)                    3.357941
# Sting, The (1973)                            3.329843
# Cinderella (1950)                            3.245412
# Field of Dreams (1989)                       3.222311
# dtype: float64

# %% [markdown]
# The last thing we have to do is filter out movies I've already rated, as recommending a movie I've already watched isn't helpful:

# %%
filteredSims = simCandidates.drop(myRatings.index)
filteredSims.head(10)
# Out:
# Return of the Jedi (1983)                    7.178172
# Raiders of the Lost Ark (1981)               5.519700
# Indiana Jones and the Last Crusade (1989)    3.488028
# Bridge on the River Kwai, The (1957)         3.366616
# Back to the Future (1985)                    3.357941
# Sting, The (1973)                            3.329843
# Cinderella (1950)                            3.245412
# Field of Dreams (1989)                       3.222311
# Wizard of Oz, The (1939)                     3.200268
# Dumbo (1941)                                 2.981645
# dtype: float64

# %% [markdown]
# There we have it!

# %% [markdown]
# ## Exercise

# %% [markdown]
# Can you improve on these results? Perhaps a different method or min_periods value on the correlation computation would produce more interesting results.
#
# Also, it looks like some movies similar to Gone with the Wind - which I hated - made it through to the final list of recommendations. Perhaps movies similar to ones the user rated poorly should actually be penalized, instead of just scaled down?
#
# There are also probably some outliers in the user rating data set - some users may have rated a huge amount of movies and have a disporportionate effect on the results. Go back to earlier lectures to learn how to identify these outliers, and see if removing them improves things.
#
# For an even bigger project: we're evaluating the result qualitatively here, but we could actually apply train/test and measure our ability to predict user ratings for movies they've already watched. Whether that's actually a measure of a "good" recommendation is debatable, though!

# %% [markdown]
# ### Comments:
# * **Outliers**: People that rates too many movies probably are doing fake rating or in case that it's true, we should check the range of their rating as they could be people that like any kind of movie, so the variability in their rating criteria could be important.
# * **The value range of the current rating system** do not represent well when a person do not like a movie, usually they give a rate lower than 3 for those movies, althoug it's still a positive value, and computer don't see this as something "negative", so I'm going to treat the values lower or equal to 3 as something negative and higher than 3 as something positive.
# * **Similarity criteria** is given by the correlation between the rates given by users to the movies, but we can decide when the level of the correlation is enough or not to assume similarity by a threshold, so far as long as there is a correlation (eather negative or positive) with a minimum of "100" samples, it is given the similarity, but should be suggested a movie with a negative correlation with the user's movie rated?
#
# New recommending system:
#  - Remove outliers considering the amount of rate given by a person and the variety and quality of the rates
#  - Calculate the correlation base of a given amount of n common viewers.
#  - Give a similarity value to a new recomended movie given the person's rates of his movies, if the person movie rate is greater than 3 [4, 5], recommend similar movies as "You probably like this...", if the rate is 3, keep those movies as "New for you to discover..." and if the rate is lower than 3, do not suggest new similar movies to that movies.

# %% [markdown]
# # Data Processing

# %% [markdown]
# ## Removing outliers

# %%
userRatings.shape
# Out:
# (944, 1664)

# %%
user_rateing_percentage = 100 - userRatings.isna().sum(axis = 1)*100/1664
user_rateing_percentage.sort_values(ascending = False)
# Out:
# user_id
# 405    44.230769
# 655    40.745192
# 13     37.980769
# 450    32.331731
# 276    31.009615
#          ...
# 147     1.201923
# 475     1.201923
# 93      1.201923
# 300     1.141827
# 0       0.180288
# Length: 944, dtype: float64

# %%
user_rateing_percentage.describe()
# Out:
# count    944.000000
# mean       6.346765
# std        6.047046
# min        0.180288
# 25%        1.983173
# 50%        3.846154
# 75%        8.849159
# max       44.230769
# dtype: float64

# %%
# Ploting the distribution of the rating percentage of users
user_rateing_percentage.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
IQR = 8.849159 - 1.983173
print(9 + (1.5*IQR))
# Out:
# 19.298979000000003

# %% [markdown]
# As we can see from the user rating variable description and the plot, most of the users rated around 6% of the movies in the database, 75% of the rated less than 9% of the movies, so it indicate that people with more than 20% of rated movies are eather experts or people that rate movies for fun.
#
# As result, I'm going to keep out those people that rated more than 20% of the movies.

# %%
# Numer of people that rated more than 20% of the movies
user_rateing_percentage[user_rateing_percentage>20].count()

print("There are {} people that rated more than 20% of the movies in the dataset".format(user_rateing_percentage[user_rateing_percentage>20].count()))
# Out:
# There are 35 people that rated more than 20% of the movies in the dataset

# %%
outlier_users = user_rateing_percentage[user_rateing_percentage>20].index

# %%
outlier_users
# Out:
# Int64Index([  7,  13,  59,  92,  94, 130, 181, 201, 222, 234, 276, 279, 293,
#             303, 308, 378, 393, 405, 406, 416, 417, 429, 435, 450, 537, 551,
#             561, 592, 655, 682, 758, 796, 846, 880, 896],
#            dtype='int64', name='user_id')

# %%
userRatings
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# 5                              NaN           NaN                    2.0
# 6                              NaN           NaN                    NaN
# 7                              NaN           NaN                    NaN
# 8                              NaN           NaN                    NaN
# 9                              NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# 0                        NaN         NaN                          NaN
# ...

# %%
new_userRatings = userRatings.drop(outlier_users)

# %%
new_userRatings.shape
# Out:
# (909, 1664)

# %% [markdown]
# As we can see now we pass from having 944 users to have now 909 (944 - 35)

# %%
user_rateing_percentage = 100 - new_userRatings.isna().sum(axis = 1)*100/1664
user_rateing_percentage.sort_values(ascending = False)
user_rateing_percentage.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## Correlation

# %%
corrMatrix = new_userRatings.corr(method='pearson', min_periods=100)
corrMatrix.head()
# Out:
# title                      'Til There Was You (1997)  1-900 (1994)  \
# title
# 'Til There Was You (1997)                        NaN           NaN
# 1-900 (1994)                                     NaN           NaN
# 101 Dalmatians (1996)                            NaN           NaN
# 12 Angry Men (1957)                              NaN           NaN
# 187 (1997)                                       NaN           NaN
#
# title                      101 Dalmatians (1996)  12 Angry Men (1957)  \
# title
# 'Til There Was You (1997)                    NaN                  NaN
# 1-900 (1994)                                 NaN                  NaN
# 101 Dalmatians (1996)                        NaN                  NaN
# 12 Angry Men (1957)                          NaN                  1.0
# 187 (1997)                                   NaN                  NaN
#
# title                      187 (1997)  2 Days in the Valley (1996)  \
# title
# ...

# %%
corrMatrix.index
# Out:
# Index([''Til There Was You (1997)', '1-900 (1994)', '101 Dalmatians (1996)',
#        '12 Angry Men (1957)', '187 (1997)', '2 Days in the Valley (1996)',
#        '20,000 Leagues Under the Sea (1954)', '2001: A Space Odyssey (1968)',
#        '3 Ninjas: High Noon At Mega Mountain (1998)', '39 Steps, The (1935)',
#        ...
#        'Yankee Zulu (1994)', 'Year of the Horse (1997)', 'You So Crazy (1994)',
#        'Young Frankenstein (1974)', 'Young Guns (1988)',
#        'Young Guns II (1990)', 'Young Poisoner's Handbook, The (1995)',
#        'Zeus and Roxanne (1997)', 'unknown',
#        'Á köldum klaka (Cold Fever) (1994)'],
#       dtype='object', name='title', length=1664)

# %%
'aa' in ('aasd')
# Out:
# True

# %%
myRatings.index[0] in (corrMatrix.index)
# Out:
# True

# %%
corrMatrix[myRatings.index[0]].dropna()>0.2
# Out:
# title
# 2001: A Space Odyssey (1968)                    False
# Abyss, The (1989)                                True
# African Queen, The (1951)                        True
# Air Force One (1997)                             True
# Aladdin (1992)                                   True
#                                                 ...
# When Harry Met Sally... (1989)                  False
# While You Were Sleeping (1995)                   True
# Willy Wonka and the Chocolate Factory (1971)    False
# Wizard of Oz, The (1939)                         True
# Young Frankenstein (1974)                        True
# Name: Empire Strikes Back, The (1980), Length: 144, dtype: bool

# %%
def movie_recomended(user_ratings, n, top_n = 10):
    corrMatrix = new_userRatings.corr(method='pearson', min_periods=n)
    simCandidates = pd.Series()
    sosoCandidates = pd.Series()
    not_likeCandidates = pd.Series()
    
    for i in range(0, len(user_ratings.index)):
        if user_ratings.index[i] in corrMatrix.index:
            if user_ratings[i] >=4:
                sims = corrMatrix[user_ratings.index[i]].dropna()
                sims = sims.map(lambda x: x  * user_ratings[i])
                simCandidates = simCandidates.append(sims)
            if user_ratings[i] == 3:
                soso_sims = corrMatrix[user_ratings.index[i]].dropna()
                sosoCandidates = sosoCandidates.append(soso_sims)
            else:
                not_like = corrMatrix[user_ratings.index[i]].dropna()
                not_likeCandidates = not_likeCandidates.append(not_like)

            # Grouping the movies that came in more than one time and adding the score
            simCandidates = simCandidates.groupby(simCandidates.index).sum()
            sosoCandidates = sosoCandidates.groupby(sosoCandidates.index).sum()
            not_likeCandidates = not_likeCandidates.groupby(not_likeCandidates.index).sum()

            # Removing user rated movies from the suggestions:
            simCandidates.drop(user_ratings.index, inplace = True, errors = 'ignore')


            # Removing similarity movies to the user low rated movies 
            simCandidates.drop(not_likeCandidates.index, inplace = True, errors = 'ignore')
        
            # Sorting the suggestion 
            simCandidates.sort_values(inplace = True, ascending = False)
            sosoCandidates.sort_values(inplace = True, ascending = False)
            not_likeCandidates.sort_values(inplace = True, ascending = False)
        
        return simCandidates.head(top_n), sosoCandidates.head(top_n), not_likeCandidates.head(top_n)

# %%
myRatings
# Out:
# title
# Empire Strikes Back, The (1980)    5.0
# Gone with the Wind (1939)          1.0
# Star Wars (1977)                   5.0
# Name: 0, dtype: float64

# %%
movie_recomended(myRatings, 200)[0]
# Out:
# C:\Users\alero\AppData\Local\Temp\ipykernel_12020\835071941.py:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   simCandidates = pd.Series()
# C:\Users\alero\AppData\Local\Temp\ipykernel_12020\835071941.py:4: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   sosoCandidates = pd.Series()
# C:\Users\alero\AppData\Local\Temp\ipykernel_12020\835071941.py:5: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   not_likeCandidates = pd.Series()
# C:\Users\alero\AppData\Local\Temp\ipykernel_12020\835071941.py:13: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# # My system:
# Empire Strikes Back, The (1980)               5.000000
# Star Wars (1977)                              3.714886
# Return of the Jedi (1983)                     3.670701
# Raiders of the Lost Ark (1981)                2.746253
# Bridge on the River Kwai, The (1957)          2.174638
# Star Trek III: The Search for Spock (1984)    2.019442
# Star Trek: The Wrath of Khan (1982)           1.944476
# Princess Bride, The (1987)                    1.673545
# Aladdin (1992)                                1.668797
# Field of Dreams (1989)                        1.660334
# dtype: float64
#
#
#
# # Original
# Empire Strikes Back, The (1980)              8.877450
# Star Wars (1977)                             8.870971
# Return of the Jedi (1983)                    7.178172
# Raiders of the Lost Ark (1981)               5.519700
# Indiana Jones and the Last Crusade (1989)    3.488028
# Bridge on the River Kwai, The (1957)         3.366616
# Back to the Future (1985)                    3.357941
# Sting, The (1973)                            3.329843
# Cinderella (1950)                            3.245412
# Field of Dreams (1989)                       3.222311

# %%
movie_recomended(myRatings, 100)[1]
# Out:
# Adding sims for Empire Strikes Back, The (1980)...
# C:\Users\alero\AppData\Local\Temp\ipykernel_12020\112695089.py:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   simCandidates = pd.Series()
# C:\Users\alero\AppData\Local\Temp\ipykernel_12020\112695089.py:4: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   sosoCandidates = pd.Series()
# C:\Users\alero\AppData\Local\Temp\ipykernel_12020\112695089.py:5: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   not_likeCandidates = pd.Series()
# ...

# %%
movie_recomended(myRatings, 100)[2]
# Out:
# Adding sims for Empire Strikes Back, The (1980)...
# C:\Users\alero\AppData\Local\Temp\ipykernel_12020\1320240043.py:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   simCandidates = pd.Series()
# C:\Users\alero\AppData\Local\Temp\ipykernel_12020\1320240043.py:4: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   sosoCandidates = pd.Series()
# C:\Users\alero\AppData\Local\Temp\ipykernel_12020\1320240043.py:5: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   not_likeCandidates = pd.Series()
# ...

# %%
like = movie_recomended(myRatings, 100)[0]
like
# Out:
# Adding sims for Empire Strikes Back, The (1980)...
# C:\Users\alero\AppData\Local\Temp\ipykernel_12020\1320240043.py:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   simCandidates = pd.Series()
# C:\Users\alero\AppData\Local\Temp\ipykernel_12020\1320240043.py:4: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   sosoCandidates = pd.Series()
# C:\Users\alero\AppData\Local\Temp\ipykernel_12020\1320240043.py:5: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   not_likeCandidates = pd.Series()
# ...

# %%
like
# Out:
# Return of the Jedi (1983)                     3.670701
# Raiders of the Lost Ark (1981)                2.746253
# Bridge on the River Kwai, The (1957)          2.174638
# Star Trek III: The Search for Spock (1984)    2.019442
# Star Trek: The Wrath of Khan (1982)           1.944476
# Princess Bride, The (1987)                    1.673545
# Aladdin (1992)                                1.668797
# Field of Dreams (1989)                        1.660334
# Sting, The (1973)                             1.633730
# Lion King, The (1994)                         1.626227
# dtype: float64

# %%
not_like = movie_recomended(myRatings, 100)[2]
not_like
# Out:
# Adding sims for Empire Strikes Back, The (1980)...
# C:\Users\alero\AppData\Local\Temp\ipykernel_12020\1320240043.py:3: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   simCandidates = pd.Series()
# C:\Users\alero\AppData\Local\Temp\ipykernel_12020\1320240043.py:4: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   sosoCandidates = pd.Series()
# C:\Users\alero\AppData\Local\Temp\ipykernel_12020\1320240043.py:5: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   not_likeCandidates = pd.Series()
# ...

# %%
like[~like.index.isin(not_like.index)]
# Out:
# Sting, The (1973)        1.633730
# Lion King, The (1994)    1.626227
# dtype: float64
